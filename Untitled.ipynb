# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
# %matplotlib inline
import h5py
import numpy as np
import mahotas as mh
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from threed import ThreeD

# %%
DATA = '/home/d/data/toufiq/segmentation.h5'

# %%
with h5py.File(DATA,'r') as f:
    vol = f[f.keys()[0]][0:10,0:300,0:300]

# %%
imshow(vol[0])

# %%
LABELID = 32

# %%
# 1. thresholding
thresholded = ThreeD.threshold(vol, LABELID)
imshow(thresholded[0])

thresholded = np.repeat(thresholded, 10, axis=0)

# %%
imshow(ThreeD.threshold(vol, 32)[8])

# %%
# 2. smoothing
thresholded = np.swapaxes(thresholded, 0, 1)
smoothed = ThreeD.smoothen(thresholded)
imshow(smoothed[0])

# %%
# 3. marching cubes
ThreeD.create_mesh(smoothed, '/tmp/out.stl')
